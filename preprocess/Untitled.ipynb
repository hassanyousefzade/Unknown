# %%
import os
import glob

# %%
paths = glob.glob("/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/*/argument*.pt")

# %%
paths
# Out:
# ['/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0065.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0070.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0075.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0080.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0085.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0090.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0095.jpg.pt',
#  '/media/hassan-hossein/B660FEE360FEA8EF/casia-ds/preposess/casia_test_spoof_26_NM_3/argument_50_cropped_0100.jpg.pt',
# ...

# %%
for path in paths:
    
    os.system("rm -r "+path)
